# %%
import pandas as pd
import csv

# %%
df=pd.read_csv("/Users/macos/Downloads/sra_result.csv.download/temp.csv",header=0,on_bad_lines='skip', quoting=csv.QUOTE_NONE)
# Out:
# /Users/macos/miniconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3441: DtypeWarning: Columns (8,9,17) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
counts=df['Instrument'].value_counts(normalize=True)

# %%
len(counts)
# Out:
# 15

# %%
counts
# Out:
# Illumina NovaSeq 6000      0.675411
# NextSeq 550                0.127677
# Illumina MiSeq             0.068742
# GridION                    0.066579
# NextSeq 500                0.032803
# MinION                     0.014440
# Ion Torrent S5             0.004508
# unspecified                0.003819
# Illumina MiniSeq           0.003517
# NextSeq 1000               0.001686
# Illumina HiSeq 2500        0.000554
# Ion Torrent Proton         0.000202
# Ion GeneStudio S5 Prime    0.000037
# Sequel II                  0.000013
# NextSeq 2000               0.000013
# Name: Instrument, dtype: float64

# %%
Technology = {'Platform': ['Illumina','Oxford Nanopore','{Ion Torrent,BGISEQ,PacBio}'],
        'Number of Sequences': [ 211258,33782,665]
        }

df = pd.DataFrame(Technology, columns = ['Platform', 'Number of Sequences'])

# %%
import matplotlib.pyplot as plt
fig, ax = plt.subplots()
plt.rcParams['font.sans-serif'] = 'Arial'
plt.rcParams['font.family'] = 'sans-serif'
plt.rcParams['text.color'] = 'black'
plt.rcParams['axes.labelcolor']= '#909090'
plt.rcParams['xtick.color'] = '#909090'
plt.rcParams['ytick.color'] = '#909090'
plt.rcParams['font.size']=14
color_palette_list = [ '#66CCEE', '#4477AA','#BBBBBB','darkblue','blueviolet']
labels =['NextSeq 550','Illumina NovaSeq 6000','Illumina MiSeq ','GridION','Others']

explode=(0,0,0)
sizes=[12.77,67.54,6.87,6.65,6.17]
patches, texts, autotexts  =  ax.pie(sizes,labels=labels,  
       colors=color_palette_list[0:5], 
        autopct='%1.1f%%', 
       shadow=False, startangle=0,   
       pctdistance=1.2,labeldistance=1.5)
# [text.set_color('red') for text in texts]
# texts[0].set_color('#4477AA')
# texts[1].set_color('#66CCEE')
# texts[2].set_color('#BBBBBB')
# autotexts[0].set_color('#4477AA')
# autotexts[1].set_color('#66CCEE')
# autotexts[2].set_color('#BBBBBB')
# [autotext.set_color('black') for autotext in autotexts]
# plt.title("Sequencing technologies in SRA database (246679 submissions)")
# ax.axis('equal')
plt.title("Sequencing technologies in SRA database")
ax.legend(frameon=False, bbox_to_anchor=(2.5,0.9))
plt.savefig('pie_SRA.png', dpi=300, bbox_inches = "tight")
plt.savefig('pie_SRA.pdf', dpi=300, bbox_inches = "tight")

# %%
import matplotlib.pyplot as plt
fig, ax = plt.subplots()
plt.rcParams['font.sans-serif'] = 'Arial'
plt.rcParams['font.family'] = 'sans-serif'
plt.rcParams['text.color'] = 'black'
plt.rcParams['axes.labelcolor']= '#909090'
plt.rcParams['xtick.color'] = '#909090'
plt.rcParams['ytick.color'] = '#909090'
plt.rcParams['font.size']=14
color_palette_list = ['#4477AA', '#66CCEE', '#BBBBBB','darkblue','blueviolet']
labels =['Illumina','Oxford Nanopore','PacBio','Others']

explode=(0,0,0)
sizes=[80.49,12.46,3.85,3.21]
patches, texts, autotexts  =  ax.pie(sizes,labels=labels,  
       colors=color_palette_list[0:5], 
        autopct='%1.1f%%', 
       shadow=False, startangle=0,   
       pctdistance=1.2,labeldistance=1.5)

plt.title("Sequencing technologies in GISAID database")
# ax.axis('equal')
# ax.set_title("Elephant in the Valley Survey Respondent Make-up")
ax.legend(frameon=False, bbox_to_anchor=(2.2,0.9))
plt.savefig('pie_GISAID.png', dpi=300, bbox_inches = "tight")
plt.savefig('pie_SRA.pdf', dpi=300, bbox_inches = "tight")

# %%
import matplotlib.pyplot as plt
fig, ax1 = plt.subplots(figsize = (5,5)) 
explode =(0,0,0)
labels=['']
ax1.pie(df['Number of Sequences'], explode = explode, autopct=None, shadow = False) 
# plt.title(“Top five teams with the most goals among the top 15 highest goal scorers \nin the premier league 2019/20 mid-season”, fontsize = 24) 
legend=['Illumina: 85.98%','Oxford Nanopore: 13.75%','Ion Torrent,BGISEQ,PacBio: 0.27%']
ax1.legend(legend, bbox_to_anchor=(1,0.5))
# ax1.legend(df['Platform'], loc = "right") 
plt.tight_layout() 
plt.title("Sequencing technologies in SRA database (246679 submissions)")
# plt.show()
plt.savefig('pie_SRA.png', dpi=300, bbox_inches = "tight")
plt.savefig('pie_SRA.pdf', dpi=300, bbox_inches = "tight")

# %%
# import matplotlib.pyplot as plt
# fig1, ax1 = plt.subplots()
# explode = (0.1, 0.1, 0, 0, 1)
# ax1.pie(df['Number of Sequences'], explode=explode, labels=df['Platform'], autopct='%1.1f%%',
#     shadow=True, startangle=90)
# ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.

# plt.show()

# %%
df.plot.pie(y='Number', figsize=(7, 7),fontsize=10,labels=df["Platform"],labeldistance=1,rotatelabels=90)

# %%
plot
