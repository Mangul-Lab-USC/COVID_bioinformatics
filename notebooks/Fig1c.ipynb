# %%
# figure 1a: number of sars cov2 genomes sequenced vs date for gisaid
# figure 1d: number of sars cov2 genomes sequenced vs date for ncbi
# a and d aligned by months: date from jan20 till octobers
# figure 1b: number of genomes sequenced vs number of covid19 cases for gisaid
# figure 1c: total number of studies vs date
# figure 1e: (number of sequences/number of reported cases) vs gdp per capita for gisaid
# figure 1f: histogram (harman)
# extra: copy of figure 1b and 1e for ncbi
#copy for ncbi

# %%
import pandas as pd

# %%
df=pd.read_csv('../csv/wastewater.csv',header=0)

# %%
# df

# %%
# df.Date

# %%
df['Date'] =pd.to_datetime(df.Date)
df['month_year'] = pd.to_datetime(df['Date']).dt.to_period('M')

# %%
# df.Date

# %%
df=df.sort_values(by='month_year')

# %%
# df

# %%
 df['cumulative']=df['n_samples'].cumsum()

# %%
# df.Date

# %%
df1=pd.read_csv('../csv/outbreak_investigations.csv',header=0)

# %%
# df1

# %%
df1['month_year'] = pd.to_datetime(df1['Date']).dt.to_period('M')

# %%
df1=df1.sort_values(by='month_year')

# %%
# df1.Date

# %%
 df1['cumulative']=df1['Number of genomes sequenced by country/region'].cumsum()

# %%
df = df.reset_index(drop=True)

# %%
df
# Out:
#                                                Coutry      Date_publication  \
# 0                                     Paris\n(France)         May 6th, 2020
# 1                                     The Netherlands        May 20th, 2020
# 2   Wuhan\n(China)\n*used wastewater in septic tan...        May 14th, 2020
# 3                            Santa Catalina (Brazil)        June 29th, 2020
# 4   Federal State of North Rhine-Westphalia (Germany)    January 20th, 2020
# 5                             Rome and Milan\n(Italy)  September 20th, 2020
# 6                                           Australia      August 1st, 2020
# 7                                  Istanbul\n(Turkey)         May 6th, 2020
# 8                                    Valencia (Spain)      April 29th, 2020
# 9                                      Massachusetts        April 7th, 2020
# 10                                              Japan       June 18th, 2020
# ...

# %%
df1 = df1.reset_index(drop=True)

# %%
df1.index
# Out:
# RangeIndex(start=0, stop=28, step=1)

# %%
df['month_year']
# Out:
# 0     2020-03
# 1     2020-03
# 2     2020-03
# 3     2020-03
# 4     2020-04
# 5     2020-04
# 6     2020-04
# 7     2020-04
# 8     2020-04
# 9     2020-05
# 10    2020-05
# 11    2020-06
# 12    2020-06
# 13    2020-06
# 14    2020-07
# Name: month_year, dtype: period[M]

# %%
# df['level_0']

# %%
(df.dtypes)
# Out:
# Coutry                                                                                       object
# Date_publication                                                                             object
# Date_sample_collection                                                                       object
# Date                                                                                 datetime64[ns]
# n_samples                                                                                     int64
# Total number of samples used for analysis (combined with publicly available data)             int64
# Method of PCR Analysis                                                                       object
# Citation                                                                                      int64
# month_year                                                                                period[M]
# ...

# %%
df['ym'] = df.month_year.values.astype('datetime64[M]')
df1['ym'] = df1.month_year.values.astype('datetime64[M]')

# %%
df
# Out:
#                                                Coutry      Date_publication  \
# 0                                     Paris\n(France)         May 6th, 2020
# 1                                     The Netherlands        May 20th, 2020
# 2   Wuhan\n(China)\n*used wastewater in septic tan...        May 14th, 2020
# 3                            Santa Catalina (Brazil)        June 29th, 2020
# 4   Federal State of North Rhine-Westphalia (Germany)    January 20th, 2020
# 5                             Rome and Milan\n(Italy)  September 20th, 2020
# 6                                           Australia      August 1st, 2020
# 7                                  Istanbul\n(Turkey)         May 6th, 2020
# 8                                    Valencia (Spain)      April 29th, 2020
# 9                                      Massachusetts        April 7th, 2020
# 10                                              Japan       June 18th, 2020
# ...

# %%
df=df.drop_duplicates(subset='month_year', keep="last")
df1=df1.drop_duplicates(subset='month_year', keep="last")

# %%
# df1 = df1.reset_index(drop=True)

# df = df.reset_index(drop=True)

# %%
df
# Out:
#                                Coutry      Date_publication  \
# 3            Santa Catalina (Brazil)        June 29th, 2020
# 8                    Valencia (Spain)      April 29th, 2020
# 10                              Japan       June 18th, 2020
# 13                     Czech Republic       July 30th, 2020
# 14  Santa Clara County \n(California)  September 15th, 2020
#
#                     Date_sample_collection       Date  n_samples  \
# 3    October 30th, 2019 - March 4th, 2020  2020-03-04          6
# 8            February 12- April 14th, 2020 2020-04-14         15
# 10       March 17th, 2020 - May 7th, 2020  2020-05-07         13
# 13                      April - June 2020  2020-06-30        112
# 14  March 16th - May 31, June 2 - July 12  2020-07-12         89
#
#     Total number of samples used for analysis (combined with publicly available data)  \
# 3                                                   6
# 8                                                  15
# ...

# %%
df1.index
# Out:
# Int64Index([0, 1, 9, 18, 22, 24, 25, 27], dtype='int64')

# %%
# fig=plt.figure
# fig.set_size_inches

# %%
# 61 mm to inches: 2.40157
# make the figure a square
# 600 is the dpi

# %%
2.40157*300
# Out:
# 720.471

# %%
# keep months only
# one study should count as one
# log scale?
from scipy.interpolate import interpolate
import matplotlib.pyplot as plt
fig=plt.figure(figsize=(2.40157, 2.40157))
ax2 = fig.add_subplot(111)
# ax2 = fig.gca()
plt.rcParams["font.family"] = "Helvetica"

ax2.tick_params(axis="x", labelsize=5.0)

# plt.rc('axes', titlesize=0.5)
# # plt.rc('axes', labelsize=5.5)
ax2.tick_params(axis="y", labelsize=5.5)
# plt.rc('xtick', labelsize=4) 
# plt.rc('ytick', labelsize=5.5) 
# plt.plot(df1['Date'], df1['cumulative'],linewidth=7.0)
ax2.plot(df['ym'], df.index,linewidth=1.0,color="#EE7733",marker='s',markersize=2)
ax2.plot(df1['ym'], df1.index,linewidth=1.0,color="#44AA99",marker='^',markersize=2)
# plt.gcf().set_size_inches(10, 10)
# plt.gcf().set_size_inches(1.416, 2.458)
# plt.gcf().set_size_inches(2.416, 2.458)
# plt.set_xlabels(my_xticks)
labels=["Genomes Sequenced","WWTP Samples"]
ax2.legend(labels,loc="lower right", prop={'size': 4.5},edgecolor="white")
# plt.yscale('log') 
ax2.set_xlabel("Date", fontsize=6)
# plt.tight_layout()
# plt.xlabel('xlabel', fontsize=18)
# plt.ylabel('ylabel', fontsize=16)
ax2.set_ylabel("Total number of studies", fontsize=6)
# plt.grid(color="#DDDDDD")
positions = ('2019-12','2020-01','2020-02','2020-03','2020-04','2020-05','2020-06','2020-07','2020-08','2020-09','2020-10')
labels1 = ('Dec','Jan-20','Feb','Mar','Apr','May','Jun','Jul','Aug','Sep','Oct')
# ax2.set_xticks(labels1)
# ax2.tick_params(axis='x', rotation=45)
plt.xticks(positions, labels1)
#  ax.set_xlabel
# ax2.set_xlabel(['Dec','Jan-20','Feb','Mar','Apr','May','Jun','Jul','Aug','Sep','Oct'])
# plt.show()
# plt.grid(linewidth=0.3,color="#DDDDDD")
# fig.set_size_inches(2.40157, 2.40157)
fig.savefig("combined_samples_vs_time.png",dpi=300, bbox_inches = "tight")
fig.savefig("combined_samples_vs_time.pdf",dpi=300, bbox_inches = "tight")

# %%
df1
# Out:
#     index                       Location   Date of publication  \
# 0       1                Northern France      April 29th, 2020
# 1       0  Guangdong Province (China)\n        April 30th 2020
# 9       2    Connecticut (United States)        May 28th, 2020
# 18     15                         Brazil       July 23rd, 2020
# 22      8         Aotearoa (New Zealand)     August 20th, 2020
# 24     12                        Morocco       June 25th, 2020
# 25     23     Washington (United States)  September 30th, 2020
# 27     22       Norfolk (United Kingdom)  September 30th, 2020
#
#                            Date of sample collection         Date  \
# 0                                       December 2019  12/30/2019
# 1   January 9th- January 31th, 2020; February 5th,...  02/12/2020
# 9                                    March 14th, 2020  03/14/2020
# 18                March 5th, 2020 - April 30th, 2020   04/30/2020
# ...

# %%
import matplotlib.pyplot as plt
plt.rc('ytick', labelsize=45) 
plt.rc('xtick', labelsize=45) 
plt.rc('axes', titlesize=55)
plt.rc('axes', labelsize=55)

# plt.plot(df1['Date'], df1['cumulative'],linewidth=7.0)
plt.plot(df1['Date'], df1['cumulative'],linewidth=7.0,color="#66CCEE",marker='s',markersize=20)
plt.gcf().set_size_inches(40, 40)
# labels=["Total","Asia","Oceania","Europe","Africa","SA","NA"]
# plt.legend(labels,loc="upper left", prop={'size': 60})
plt.yscale('log') 
plt.xlabel("Date")
plt.ylim(100,100000)
plt.ylabel("Total number of genomes sequenced")
plt.grid(color="#DDDDDD")
positions = ('2019-12','2020-01','2020-02','2020-03','2020-04','2020-05','2020-06','2020-07','2020-08','2020-09','2020-10')
labels1 = ('Dec','Jan-20','Feb','Mar','Apr','May','Jun','Jul','Aug','Sep','Oct')
plt.xticks(positions, labels1)
plt.tick_params(axis='x',pad=20)
plt.show()
plt.savefig("genomese_sequenced.png",dpi=300)

# %%
plt.show()
