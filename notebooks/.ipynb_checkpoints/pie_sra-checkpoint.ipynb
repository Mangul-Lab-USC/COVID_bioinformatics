# 26        269419006                 0       1969      236          NaN
# 27        185733863                 0       1937      164          NaN
# 28        483263428                 0       1953      427          NaN
# 29         78105339                 0       1955       69          NaN
# ...             ...               ...        ...      ...          ...
# 245675    118148011                 0        183       20          NaN
# 245676     11080510                 0        180        2          NaN
# 245677       888775                 0         85        0          NaN
# 245678  20124958500          67083195        300    12932          NaN
# 245679   2232781003           8267029        270     1183          NaN
# 245680   1456539874           5184909        280      768          NaN
# 245681  18391209000          61304030        300    11686          NaN
# 245682  10276752900          34255843        300     6582          NaN
# 245683   8902750200          29675834        300     5708          NaN
# 245684   1484179677           5239723        283      772          NaN
# 245685  11539256400          38464188        300     7223          NaN
# 245686   1036248134           3566583        290      548          NaN
# 245687    178572683            621613        287       60          NaN
# 245688    109719335            380092        288       37          NaN
# 245689   8728641275          29362226        132     2247     assembly
# 245690    726432925           2581610        138      209     assembly
# 245691     24513827             75736        131        8     assembly
# 245692    134313125            449654        132       40     assembly
# 245693     19977094              7866        109        5     assembly
# 245694    212641182             69217        107       47     assembly
# 245695      1477468               662        113        0     assembly
# 245696      8325534              2947        108        2     assembly
# 245697     23696161                 0        623       20          NaN
# 245698      7650166             17208        433        3          NaN
# 245699    304113442                 0        629      267          NaN
# 245700    190194752            420515        451       88          NaN
# 245701    359000999                 0        633      316          NaN
# 245702    159508570            358251        444       74          NaN
# 245703    260956833                 0        658      229          NaN
# 245704    226957916            502865        450      103          NaN
#
#                                             download_path  ...  \
# 0       https://sra-download.ncbi.nlm.nih.gov/traces/s...  ...
# 1       https://sra-download.ncbi.nlm.nih.gov/traces/s...  ...
# 2       https://sra-download.ncbi.nlm.nih.gov/traces/s...  ...
# 3       https://sra-download.ncbi.nlm.nih.gov/traces/s...  ...
# 4       https://sra-download.ncbi.nlm.nih.gov/traces/s...  ...
# 5       https://sra-download.ncbi.nlm.nih.gov/traces/s...  ...
# 6       https://sra-download.ncbi.nlm.nih.gov/traces/s...  ...
# 7       https://sra-download.ncbi.nlm.nih.gov/traces/s...  ...
# 8       https://sra-download.ncbi.nlm.nih.gov/traces/s...  ...
# 9       https://sra-download.ncbi.nlm.nih.gov/traces/s...  ...
# 10      https://sra-download.ncbi.nlm.nih.gov/traces/s...  ...
# 11      https://sra-download.ncbi.nlm.nih.gov/traces/s...  ...
# 12      https://sra-download.ncbi.nlm.nih.gov/traces/s...  ...
# 13      https://sra-download.ncbi.nlm.nih.gov/traces/s...  ...
# 14      https://sra-download.ncbi.nlm.nih.gov/traces/s...  ...
# 15      https://sra-download.ncbi.nlm.nih.gov/traces/s...  ...
# 16      https://sra-download.ncbi.nlm.nih.gov/traces/s...  ...
# 17      https://sra-download.ncbi.nlm.nih.gov/traces/s...  ...
# 18      https://sra-download.ncbi.nlm.nih.gov/traces/s...  ...
# 19      https://sra-download.ncbi.nlm.nih.gov/traces/s...  ...
# 20      https://sra-download.ncbi.nlm.nih.gov/traces/s...  ...
# 21      https://sra-download.ncbi.nlm.nih.gov/traces/s...  ...
# 22      https://sra-download.ncbi.nlm.nih.gov/traces/s...  ...
# 23      https://sra-download.ncbi.nlm.nih.gov/traces/s...  ...
# 24      https://sra-download.ncbi.nlm.nih.gov/traces/s...  ...
# 25      https://sra-download.ncbi.nlm.nih.gov/traces/s...  ...
# 26      https://sra-download.ncbi.nlm.nih.gov/traces/s...  ...
# 27      https://sra-download.ncbi.nlm.nih.gov/traces/s...  ...
# 28      https://sra-download.ncbi.nlm.nih.gov/traces/s...  ...
# 29      https://sra-download.ncbi.nlm.nih.gov/traces/s...  ...
# ...                                                   ...  ...
# 245675  https://sra-downloadb.be-md.ncbi.nlm.nih.gov/s...  ...
# 245676  https://sra-download.ncbi.nlm.nih.gov/traces/s...  ...
# 245677  https://sra-download.ncbi.nlm.nih.gov/traces/s...  ...
# 245678  https://sra-downloadb.be-md.ncbi.nlm.nih.gov/s...  ...
# 245679  https://sra-downloadb.be-md.ncbi.nlm.nih.gov/s...  ...
# 245680  https://sra-downloadb.be-md.ncbi.nlm.nih.gov/s...  ...
# 245681  https://sra-downloadb.be-md.ncbi.nlm.nih.gov/s...  ...
# 245682  https://sra-downloadb.be-md.ncbi.nlm.nih.gov/s...  ...
# 245683  https://sra-downloadb.be-md.ncbi.nlm.nih.gov/s...  ...
# 245684  https://sra-downloadb.be-md.ncbi.nlm.nih.gov/s...  ...
# 245685  https://sra-downloadb.be-md.ncbi.nlm.nih.gov/s...  ...
# 245686  https://sra-downloadb.be-md.ncbi.nlm.nih.gov/s...  ...
# 245687  https://sra-downloadb.be-md.ncbi.nlm.nih.gov/s...  ...
# 245688  https://sra-downloadb.be-md.ncbi.nlm.nih.gov/s...  ...
# 245689  https://sra-downloadb.be-md.ncbi.nlm.nih.gov/s...  ...
# 245690  https://sra-downloadb.be-md.ncbi.nlm.nih.gov/s...  ...
# 245691  https://sra-download.ncbi.nlm.nih.gov/traces/s...  ...
# 245692  https://sra-downloadb.be-md.ncbi.nlm.nih.gov/s...  ...
# 245693  https://sra-download.ncbi.nlm.nih.gov/traces/s...  ...
# 245694  https://sra-downloadb.be-md.ncbi.nlm.nih.gov/s...  ...
# 245695  https://sra-download.ncbi.nlm.nih.gov/traces/s...  ...
# 245696  https://sra-download.ncbi.nlm.nih.gov/traces/s...  ...
# 245697  https://sra-downloadb.be-md.ncbi.nlm.nih.gov/s...  ...
# 245698  https://sra-download.ncbi.nlm.nih.gov/traces/s...  ...
# 245699  https://sra-downloadb.be-md.ncbi.nlm.nih.gov/s...  ...
# 245700  https://sra-downloadb.be-md.ncbi.nlm.nih.gov/s...  ...
# 245701  https://sra-downloadb.be-md.ncbi.nlm.nih.gov/s...  ...
# 245702  https://sra-downloadb.be-md.ncbi.nlm.nih.gov/s...  ...
# 245703  https://sra-downloadb.be-md.ncbi.nlm.nih.gov/s...  ...
# 245704  https://sra-downloadb.be-md.ncbi.nlm.nih.gov/s...  ...
#
#        Affection_Status Analyte_Type Histological_Type Body_Site  \
# 0                   NaN          NaN               NaN       NaN
# 1                   NaN          NaN               NaN       NaN
# 2                   NaN          NaN               NaN       NaN
# 3                   NaN          NaN               NaN       NaN
# 4                   NaN          NaN               NaN       NaN
# 5                   NaN          NaN               NaN       NaN
# 6                   NaN          NaN               NaN       NaN
# 7                   NaN          NaN               NaN       NaN
# 8                   NaN          NaN               NaN       NaN
# 9                   NaN          NaN               NaN       NaN
# 10                  NaN          NaN               NaN       NaN
# 11                  NaN          NaN               NaN       NaN
# 12                  NaN          NaN               NaN       NaN
# 13                  NaN          NaN               NaN       NaN
# 14                  NaN          NaN               NaN       NaN
# 15                  NaN          NaN               NaN       NaN
# 16                  NaN          NaN               NaN       NaN
# 17                  NaN          NaN               NaN       NaN
# 18                  NaN          NaN               NaN       NaN
# 19                  NaN          NaN               NaN       NaN
# 20                  NaN          NaN               NaN       NaN
# 21                  NaN          NaN               NaN       NaN
# 22                  NaN          NaN               NaN       NaN
# 23                  NaN          NaN               NaN       NaN
# 24                  NaN          NaN               NaN       NaN
# 25                  NaN          NaN               NaN       NaN
# 26                  NaN          NaN               NaN       NaN
# 27                  NaN          NaN               NaN       NaN
# 28                  NaN          NaN               NaN       NaN
# 29                  NaN          NaN               NaN       NaN
# ...                 ...          ...               ...       ...
# 245675              NaN          NaN               NaN       NaN
# 245676              NaN          NaN               NaN       NaN
# 245677              NaN          NaN               NaN       NaN
# 245678              NaN          NaN               NaN       NaN
# 245679              NaN          NaN               NaN       NaN
# 245680              NaN          NaN               NaN       NaN
# 245681              NaN          NaN               NaN       NaN
# 245682              NaN          NaN               NaN       NaN
# 245683              NaN          NaN               NaN       NaN
# 245684              NaN          NaN               NaN       NaN
# 245685              NaN          NaN               NaN       NaN
# 245686              NaN          NaN               NaN       NaN
# 245687              NaN          NaN               NaN       NaN
# 245688              NaN          NaN               NaN       NaN
# 245689              NaN          NaN               NaN       NaN
# 245690              NaN          NaN               NaN       NaN
# 245691              NaN          NaN               NaN       NaN
# 245692              NaN          NaN               NaN       NaN
# 245693              NaN          NaN               NaN       NaN
# 245694              NaN          NaN               NaN       NaN
# 245695              NaN          NaN               NaN       NaN
# 245696              NaN          NaN               NaN       NaN
# 245697              NaN          NaN               NaN       NaN
# 245698              NaN          NaN               NaN       NaN
# 245699              NaN          NaN               NaN       NaN
# 245700              NaN          NaN               NaN       NaN
# 245701              NaN          NaN               NaN       NaN
# 245702              NaN          NaN               NaN       NaN
# 245703              NaN          NaN               NaN       NaN
# 245704              NaN          NaN               NaN       NaN
#
#                                                CenterName  Submission  \
# 0                                          CANCOGEN_CPHLN  SRA1200368
# 1                                          CANCOGEN_CPHLN  SRA1200368
# 2                                          CANCOGEN_CPHLN  SRA1200368
# 3                                          CANCOGEN_CPHLN  SRA1200368
# 4                                          CANCOGEN_CPHLN  SRA1200368
# 5                                          CANCOGEN_CPHLN  SRA1200368
# 6                                          CANCOGEN_CPHLN  SRA1200368
# 7                                          CANCOGEN_CPHLN  SRA1200368
# 8                                          CANCOGEN_CPHLN  SRA1200368
# 9                                          CANCOGEN_CPHLN  SRA1200368
# 10                                         CANCOGEN_CPHLN  SRA1200368
# 11                                         CANCOGEN_CPHLN  SRA1200368
# 12                                         CANCOGEN_CPHLN  SRA1200368
# 13                                         CANCOGEN_CPHLN  SRA1200368
# 14                                         CANCOGEN_CPHLN  SRA1200368
# 15                                         CANCOGEN_CPHLN  SRA1200368
# 16                                         CANCOGEN_CPHLN  SRA1200368
# 17                                         CANCOGEN_CPHLN  SRA1200368
# 18                                         CANCOGEN_CPHLN  SRA1200368
# 19                                         CANCOGEN_CPHLN  SRA1200368
# 20                                         CANCOGEN_CPHLN  SRA1200368
# 21                                         CANCOGEN_CPHLN  SRA1200368
# 22                                         CANCOGEN_CPHLN  SRA1200368
# 23                                         CANCOGEN_CPHLN  SRA1200368
# 24                                         CANCOGEN_CPHLN  SRA1200368
# 25                                         CANCOGEN_CPHLN  SRA1200368
# 26                                         CANCOGEN_CPHLN  SRA1200368
# 27                                         CANCOGEN_CPHLN  SRA1200368
# 6                         NaN   public  184556ED83563FDF807B2E9A29CC9906
# 7                         NaN   public  047F9D76A94F11455D1EC5980791BA92
# 8                         NaN   public  C938513309BA699B76251AAD841AD2E2
# 9                         NaN   public  2B307AE8A40885842FCA4DDCF0A99166
# 10                        NaN   public  F4FAEB2DF295B6472C1FF53F418AF7A0
# 11                        NaN   public  BE6F678942D2822A9855274BA77A8B04
# 12                        NaN   public  5581347A5B7AD788F823B9FB409866D0
# 13                        NaN   public  5F234CF4A43E6C924BBA0B0F4776511D
# 14                        NaN   public  2D9A3AD21693E437876C003AD36526F7
# 15                        NaN   public  74B1A5418259D9BBC7A45C7815D27C6F
# 16                        NaN   public  09469EF4DC0D9AEB247A123762C8D669
# 17                        NaN   public  A157A2B333B477164E8614F37E754F93
# 18                        NaN   public  9A22BB7067ACD6D043A3318BA42C119E
# 19                        NaN   public  6EB39C32360A53D086CF595D8991D7B2
# 20                        NaN   public  F0ADB3421D9D0421FE978AB11B5A3705
# 21                        NaN   public  E41F5CE5E92AF259A3FBC4BC00AAD630
# 22                        NaN   public  00F10E8F4208DCF01398AAD95EF0A3CE
# 23                        NaN   public  CEA1EDDEC09258B409086AF58E05EC25
# 24                        NaN   public  600715D9AA24C0D8C09575BD34E4EEA4
# 25                        NaN   public  C69620EC90CDE76781F92380ECED4858
# 26                        NaN   public  93CE55E2B91060131A3DFC78A7A05F77
# 27                        NaN   public  A8C8D66FDFE25BD72FBEEF7D9A3DFA8A
# 28                        NaN   public  4FB40882D4361F4FC51DF8A0EE894938
# 29                        NaN   public  7C5B75D8D736635E29CBD0047D6A3257
# ...                       ...      ...                               ...
# 245675                    NaN   public  8F3C9AD29C94AF189EB219571CEF8E9D
# 245676                    NaN   public  1E37548D0B900B5C6F1F4C970DE4D029
# 245677                    NaN   public  0DBC866B682E58E7A4123259DF01BDE9
# 245678                    NaN   public  A088473FDC6DAC63F0BB0FA70BB5819D
# 245679                    NaN   public  6FD405193A3B8B4C74E4721DEFC29244
# 245680                    NaN   public  7320270C5A2EA7BD00E64D855C42E256
# 245681                    NaN   public  35466CA7DAEDEAB80ABF78BF579AB953
# 245682                    NaN   public  948690DA11AE082F558806168C688CA0
# 245683                    NaN   public  F7A282D7830BE8022DBC5C011D610BF5
# 245684                    NaN   public  B4629F80650FBC5556F28EE1D1708D8F
# 245685                    NaN   public  D58EE6A8D6994DEB668E6E7A5C810336
# 245686                    NaN   public  7B0BE202B793E74B4EA3C420CA67A399
# 245687                    NaN   public  9F771DEA989C1A8160BBE34E679F2AD2
# 245688                    NaN   public  46BCE6B9521638DCF3447D0CCEA4E406
# 245689                    NaN   public  B6E8E992B20EAE230E0D472EA928841F
# 245690                    NaN   public  91331C69198E1FE7B8624D2554426875
# 245691                    NaN   public  AE2414CDC9B387C39F215378CB6C7E9C
# 245692                    NaN   public  02ADA4B5E06BC1C3D1C5D4D13E65ED6F
# 245693                    NaN   public  FE2A4C0377F8F00483257420AD9253B1
# 245694                    NaN   public  1E063EF1DE079EE52B3D4226BBCA9FE1
# 245689  2C1D6322055E49184345EBC13F8C3384
# 245690  96285AE56A9F5222F62BD3E07FDBDF28
# 245691  69099B6650C406450AD3705AEDD0A80B
# 245692  A0C00C0F32CAB8B019803C288652E680
# 245693  17683CB6DF3A42D75EAA942D1FAE28B3
# 245694  99C6969405CB6D7B3BDC5E6E99B6E427
# 245695  E8D0AC8C4208FD1EEF29B7ED030AF6E1
# 245696  DA045105E241F3C891630DFED13B8E35
# 245697  205EC23F6CCA244D0FC802B020D0CBD4
# 245698  E7F3456377B6561F587AA5B2507FAE98
# 245699  9F822D0C7FD4157B4E410CC3530BD95A
# 245700  D01CD9CE24F3FD24DA2014BD074AD90C
# 245701  2F1887D8CC52C932AE88BD566E4C5B15
# 245702  C62FDCC87DA12483A0BED5190C3A981A
# 245703  B55A32E4702FAAB48641DA4A47C222D3
# 245704  09B5197CDEF583DDF62E6D549817A259
#
# [245705 rows x 47 columns]

# %%
df["Platform"].unique()
# Out:
# array(['OXFORD_NANOPORE', 'ILLUMINA', 'ION_TORRENT', 'BGISEQ',
#        'PACBIO_SMRT'], dtype=object)

# %%
df["Platform"].agg(['count', 'size', 'nunique'])
# Out:
# count      245705
# size       245705
# nunique         5
# Name: Platform, dtype: int64

# %%
df["Platform"].nunique()
# Out:
# 5

# %%
df = df.groupby('Platform')['Run'].nunique()

# %%
df
# Out:
# Platform
# BGISEQ                107
# ILLUMINA           211258
# ION_TORRENT           533
# OXFORD_NANOPORE     33782
# PACBIO_SMRT            25
# Name: Run, dtype: int64

# %%
plot=df.plot.pie(y='Platform', figsize=(11, 11),fontsize=50)

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# data = pd.DataFrame({'Category': np.random.choice(list('abcdefghij'), 500)})
# sizes = data['Category'].value_counts().sort_index() / data['Category'].value_counts().sum() * 100
plt.pie(df,
        autopct='%1.1f%%', shadow=True, startangle=140)
plt.axis('equal')
plt.legend( loc="best")
plt.tight_layout()
plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
# Platform
# BGISEQ                107
# ILLUMINA           211258
# ION_TORRENT           533
# OXFORD_NANOPORE     33782
# PACBIO_SMRT            25

# %%
import pandas as pd

# %%
Technology = {'Platform': ['Illumina','Oxford Nanopore','{Ion Torrent,BGISEQ,PacBio}'],
        'Number of Sequences': [ 211258,33782,665]
        }

df = pd.DataFrame(Technology, columns = ['Platform', 'Number of Sequences'])

# %%
df
# Out:
#                       Platform  Number of Sequences
# 0                     Illumina               211258
# 1              Oxford Nanopore                33782
# 2  {Ion Torrent,BGISEQ,PacBio}                  665

# %%
211258+665+33782
# Out:
# 245705

# %%
665/(211258+665+33782)
# Out:
# 0.0027064976292708737

# %%
211258/(211258+665+33782)
# Out:
# 0.8598034228037688

# %%
33782/(211258+665+33782)
# Out:
# 0.13749007956696038

# %%
df.plot.pie(y='Number of Sequences', labels=df["Platform"],figsize=(7, 7), colors=None, autopct=None, pctdistance=0.6, shadow=False, labeldistance=1.1, startangle=None, radius=None, counterclock=True, wedgeprops=None, textprops=None, center=(0, 0), frame=False, rotatelabels=True)
# plt.legend(labels, loc = "upper right")

# %%
# other
# add percentags to the legend
# Add a title: Sequencing technologies in SRA database (246679 submissions)

# %%
df['Number of Sequences']
# Out:
# 0    211258
# 1     33782
# 2       665
# Name: Number of Sequences, dtype: int64

# %%
import matplotlib.pyplot as plt

fig =plt.figure(figsize = (1,1))
ax11 = fig.add_subplot(111)
# Data to plot
sizes = [215, 130, 245, 2000]
labels = 'Python', 'C++', 'Ruby', 'Java'
colors = ['gold', 'yellowgreen', 'lightcoral', 'lightskyblue']
explode = (0.1, 0, 0, 0)  # explode 1st slice

# Plot
w,l,p = ax11.pie(sizes,  labels=labels, colors=colors,
        autopct='%1.1f%%', startangle=140, pctdistance=0.65, radius = 1, explode=explode)
[t.set_rotation(0) for t in p]
[t.set_fontsize(25) for t in p]
[t.set_fontsize(25) for t in l]
plt.axis('equal')
plt.show()

# %%
fig, ax = plt.subplots()
plt.rcParams['font.sans-serif'] = 'Arial'
plt.rcParams['font.family'] = 'sans-serif'
plt.rcParams['text.color'] = 'black'
plt.rcParams['axes.labelcolor']= '#909090'
plt.rcParams['xtick.color'] = '#909090'
plt.rcParams['ytick.color'] = '#909090'
plt.rcParams['font.size']=14
color_palette_list = ['#4477AA', '#66CCEE', '#BBBBBB']
labels =['Illumina','Oxford Nanopore','Others']

explode=(0,0,0)
sizes=[ 211258,33782,665]
patches, texts, autotexts  =  ax.pie(sizes, explode=explode, labels=labels,  
       colors=color_palette_list[0:3], autopct='%1.1f%%', 
       shadow=False, startangle=0,   
       pctdistance=1.2,labeldistance=1.5)
# [text.set_color('red') for text in texts]
texts[0].set_color('#4477AA')
texts[1].set_color('#66CCEE')
texts[2].set_color('#BBBBBB')
autotexts[0].set_color('#4477AA')
autotexts[1].set_color('#66CCEE')
autotexts[2].set_color('#BBBBBB')
# [autotext.set_color('black') for autotext in autotexts]
plt.title("Sequencing technologies in SRA database (246679 submissions)")
# ax.axis('equal')
# ax.set_title("Elephant in the Valley Survey Respondent Make-up")
ax.legend(frameon=False, bbox_to_anchor=(1.9,0.9))
plt.savefig('pie_SRA.png', dpi=300, bbox_inches = "tight")
plt.savefig('pie_SRA.pdf', dpi=300, bbox_inches = "tight")

# %%
import matplotlib.pyplot as plt
fig, ax1 = plt.subplots(figsize = (5,5)) 
explode =(0,0,0)
labels=['']
ax1.pie(df['Number of Sequences'], explode = explode, autopct=None, shadow = False) 
# plt.title(“Top five teams with the most goals among the top 15 highest goal scorers \nin the premier league 2019/20 mid-season”, fontsize = 24) 
legend=['Illumina: 85.98%','Oxford Nanopore: 13.75%','Ion Torrent,BGISEQ,PacBio: 0.27%']
ax1.legend(legend, bbox_to_anchor=(1,0.5))
# ax1.legend(df['Platform'], loc = "right") 
plt.tight_layout() 
plt.title("Sequencing technologies in SRA database (246679 submissions)")
# plt.show()
plt.savefig('pie_SRA.png', dpi=300, bbox_inches = "tight")
plt.savefig('pie_SRA.pdf', dpi=300, bbox_inches = "tight")

# %%
# import matplotlib.pyplot as plt
# fig1, ax1 = plt.subplots()
# explode = (0.1, 0.1, 0, 0, 1)
# ax1.pie(df['Number of Sequences'], explode=explode, labels=df['Platform'], autopct='%1.1f%%',
#     shadow=True, startangle=90)
# ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.

# plt.show()

# %%
df.plot.pie(y='Number', figsize=(7, 7),fontsize=10,labels=df["Platform"],labeldistance=1,rotatelabels=90)

# %%
plot
